# %% [markdown]
# # Weekly assignment 1
#
# ## Read before you start
#
# * Provide clear and complete answers in code blocks or markdown. You may add as many as you need.
# * Always motivate your answers. This can be done in markdown cells, or in comments in code.
# * Submit your results via Brightspace. Use the following filename convention: ``StudentName1_snumber1_StudentName2_snumber2_Assignment1.ipynb``.
# * Make sure you submit a fully executed version of the notebook file. The teaching assistants will not run/debug your code during grading.
# * Questions? Ask them during the workgroups, or see Brightspace for instructions on how to proceed.

# %% [markdown]
# ## Probability theory refresher
#
# For Bayesian statistics, we need both Probability Theory and (some) Calculus. In this first exercise, we will refresh some key ideas from these disciplines.
#
# Consider the following _joint probability distribution_:
#
# <table>
# <thead>
#   <tr>
#     <th>&nbsp;</th>
#     <th>&nbsp;</th>
#     <th colspan="6">B</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>&nbsp;</td>
#     <td>&nbsp;</td>
#     <td>1</td>
#     <td>2</td>
#     <td>3</td>
#     <td>4</td>
#     <td>5</td>
#     <td>6</td>
#   </tr>
#   <tr>
#     <th rowspan="2">A</th>
#     <td>H<br></td>
#     <td>1/9</td>
#     <td>5/36</td>
#     <td>1/12</td>
#     <td>1/9</td>
#     <td>5/36</td>
#     <td>1/9</td>
#   </tr>
#   <tr>
#     <td>T</td>
#     <td>1/36</td>
#     <td>1/36</td>
#     <td>1/12</td>
#     <td>1/12</td>
#     <td>1/18</td>
#     <td>1/36</td>
#   </tr>
# </tbody>
# </table>
#
# Here, random variable $A$ represents an (unfair?) coin, with possible outcomes $H$ (heads) and $T$ (tails), and $B$ a (loaded?) six-sided die, with possible outcomes $1, \ldots, 6$.
#
# 1. Compute the _marginal probability distributions_ (note: distributions, not single probabilities!) $P(A)$ and $P(B)$.
# 2. Compute the _conditional distributions_ $P(A\mid B)$ and $P(B\mid A)$.
# 3. Are $A$ and $B$ independent?
#
#
# Now we work the other way around. We consider again a coin ($C$) and a six-sided die ($D$). This is the marginal probability distribution $P(D)$:
#
# <table>
# <thead>
#   <tr>
#     <th colspan="6">D</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>1</td>
#     <td>2</td>
#     <td>3</td>
#     <td>4</td>
#     <td>5</td>
#     <td>6</td>
#   </tr>
#   <tr>
#     <td>7/80</td>
#     <td>1/8</td>
#     <td>13/40</td>
#     <td>11/80</td>
#     <td>1/10</td>
#     <td>9/40</td>
#   </tr>
# </tbody>
# </table>
#
# Furthermore, let these be the conditional probabilities of $C=H$ given $D$:
#
# <table>
# <thead>
#   <tr>
#     <th colspan="6">P(C=H | D)</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>1</td>
#     <td>2</td>
#     <td>3</td>
#     <td>4</td>
#     <td>5</td>
#     <td>6</td>
#   </tr>
#   <tr>
#     <td>8/10<br></td>
#     <td>4/13<br></td>
#     <td>4/11</td>
#     <td>5/10<br></td>
#     <td>4/9</td>
#     <td>21/50</td>
#   </tr>
# </tbody>
# </table>
#
# 4. Why does $P(C=H \mid D)$ **not** sum to 1 when you sum over the different values $D$ can take? (Note: this is really important for using Bayes' theorem throughout this course, so make sure you understand what is going on here!)
# 5. Compute the marginal probability $P(C=H)$.
# 6. Use Bayes' theorem to compute $P(D\mid C=H)$.
# 7. Are $C$ and $D$ independent?
# 8. Why **does** $P(D\mid C=H)$ sum to 1? (If it doesn't, you made a mistake. Fix it quickly before anyone sees!)

# %% [markdown]
# 1.  P(H) = P(H, b = 1) + P(H, b = 2) + P(H, b = 3) + P(H, b = 4) + P(H, b = 5) + P(H, b = 6) = 0.69444...
#     <br>
#     P(T) = P(T, b = 1) + P(T, b = 2) + P(T, b = 3) + P(T, b = 4) + P(T, b = 5) + P(T, b = 6) = 0.30555... which is equal to 1 - P(H)
# <br><br>
#     P(1) = P(H, b = 1) + P(T, b = 1) = 0.13888...
#     <br>
#     P(2) = P(H, b = 2) + P(T, b = 2) = 0.16666...
#     <br>
#     P(3) = P(H, b = 3) + P(T, b = 3) = 0.16666...
#     <br>
#     P(4) = P(H, b = 4) + P(T, b = 4) = 0.19444...
#     <br>
#     P(5) = P(H, b = 5) + P(T, b = 5) = 0.19444...
#     <br>
#     P(6) = P(H, b = 6) + P(T, b = 6) = 0.13888...
#
# 2.  P(A | B):
#     When B = 1  --> P(A = H | B = 1) = P(A = H, B = 1) / P(B = 1) = 0.8         and   P(A = T | B = 1) =  P(A = T, B = 1) / P(B = 1) = 0.2
#     <br>
#     When B = 2  --> P(A = H | B = 2) = P(A = H, B = 2) / P(B = 2) = 0.8333...   and   P(A = T | B = 2) =  P(A = T, B = 2) / P(B = 2) = 0.1666...
#     <br>
#     When B = 3  --> P(A = H | B = 3) = P(A = H, B = 3) / P(B = 3) = 0.5         and   P(A = T | B = 3) =  P(A = T, B = 3) / P(B = 3) = 0.5
#     <br>
#     When B = 4  --> P(A = H | B = 4) = P(A = H, B = 4) / P(B = 4) = 0.571429    and   P(A = T | B = 4) =  P(A = T, B = 4) / P(B = 4) = 0.428571
#     <br>
#     When B = 5  --> P(A = H | B = 5) = P(A = H, B = 5) / P(B = 5) = 0.714286    and   P(A = T | B = 5) =  P(A = T, B = 5) / P(B = 5) = 0.285714
#     <br>
#     When B = 6  --> P(A = H | B = 6) = P(A = H, B = 6) / P(B = 6) = 0.8         and   P(A = T | B = 6) =  P(A = T, B = 6) / P(B = 6) = 0.2
#
#     P(B | A):
#     When A = H:
#         P(B = 1| A = H) = P(B = 1, A = H) / P(A = H) = 0.16 and P(B = 2| A = H) = P(B = 2, A = H) / P(A = H) = 0.2 and
#         <br>
#         P(B = 3| A = H) = P(B = 3, A = H) / P(A = H) = 0.3 and P(B = 4| A = H) = P(B = 4, A = H) / P(A = H) = 0.16 and
#         <br>
#         P(B = 5| A = H) = P(B = 5, A = H) / P(A = H) = 0.2 and P(B = 6| A = H) = P(B = 6, A = H) / P(A = H) = 0.16
#     When A = T:
#         P(B = 1| A = T) = P(B = 1, A = T) / P(A = T) = 0.090909 and P(B = 2| A = T) = P(B = 2, A = T) / P(A = T) = 0.090909 and
#         <br>
#         P(B = 3| A = T) = P(B = 3, A = T) / P(A = T) = 0.272727 and P(B = 4| A = T) = P(B = 4, A = T) / P(A = T) = 0.272727 and
#         <br>
#         P(B = 5| A = T) = P(B = 5, A = T) / P(A = T) = 0.181818 and P(B = 6| A = T) = P(B = 6, A = T) / P(A = T) = 0.090909
#
# 3.  For A and B to be independent P(A, B) should be equal to the product of all marginal probabilities for each outcome B.
#     <br>
#     P(A = H, B = 1) = 0.11111... (1/9)
#     P(A = H) = 0.69444...
#     P(B = 1) = 0.13888... (5/36)
#     P(A = H) * P(B = 1) = 0.09644
#     P(A = H, B = 1) != P(A = H) * P(B = 1) since this one is already not equal we can determine that A and B are dependent.
#     <br>
#
# 4.  The probabilities of a variable conditioned on another variable (like the probability that the coin lands on heads given that the die landed on a specific number) do not necessarily sum to 1 over the conditioning variable.
#     For example P (C= H | D = 1) + P(C = H | D = 2) + ... + P(C = H | D = 6) doesn't have to equal 1 because these are not the probabilities of the die outcomes, but rather the probability of the coin being heads for each die outcome.
#     <br>
#
# 5.  P(C = H) = 6SUM_i P(C = H | D = i) * P(D = i)
#     = P(C = H | D = 1) * P(D = 1) + P(C = H | D = 2) * P(D = 2) + P(C = H | D = 3) * P(D = 3) + P(C = H | D = 4) * P(D = 4) + P(C = H | D = 5) * P(D = 5) + P(C = H | D = 6) * P(D = 6)
#     = (8/10) * (7/80) + (4/13) * (1/8) + (4/11) * (13/40) + (5/10) * (11/80) + (4/9) * (1/10) + (21/50) * (9/40) = 0.4343378011
# <br>
#
# 6.  Bayes theorem P(A|B) = (P(B|A)*P(A))/P(B)
#     P(D|C = H) = (P(C = H|D)*P(D))/P(C = H)
#     P(C = H) = 0.4343378011
#     <br>
#     P(D = i|C = H) = P(C = H|D = i) * P(D=i) / P(C = H)
#
#     P(C = H|D = 1) * P(D=1) / P(C = H) = 8/10 *     7/80    / 0.4343378011 = 0.161
#     P(C = H|D = 2) * P(D=2) / P(C = H) = 4/13 *     1/8     / 0.4343378011 = 0.089
#     P(C = H|D = 3) * P(D=3) / P(C = H) = 4/11 *     13/40   / 0.4343378011 = 0.272
#     P(C = H|D = 4) * P(D=4) / P(C = H) = 5/10 *     11/80   / 0.4343378011 = 0.158
#     P(C = H|D = 5) * P(D=5) / P(C = H) = 4/9 *      1/10    / 0.4343378011 = 0.102
#     P(C = H|D = 6) * P(D=6) / P(C = H) = 21/50 *    9/40    / 0.4343378011 = 0.218
#
#     All these probabilities sum to 1 as they should.
#
# 7.  For C and D to be independent P(C = H, D) should be equal to P(C = H) * P(D)
#     P(C = H) = 0.4343378011
#     P(C = H | D = 1) = 0.161 = P(C = H) * P(D=1) =
#
# 8. Because these are the conditional probabilities. And all conditional probabilities should sum to one.

# %% [markdown]
# # Calculus refresher
#
# In practice, the situations we are interested in often concern many variables, which means their joint probability tables become too high-dimensional to write down. At the same time, we often encounter continuous variables rather than discrete ones. That means they can take an infinite number of different values, which again we cannot write down in a probability table. Instead, we have to use some calculus to work with such distributions. We will do so many times throughout this course, but for now we will simply look at finding the maximum of a probability density function. This corresponds to the most likely value for our variable!
#
# ## The value that maximizes the probability density function
#
# An example of a probability density function is the following:
#
# $$ p(\theta \mid a, b) = \frac{\theta^{a-1} (1-\theta)^{b-1}}{B(a,b)}\qquad 0 \leq \theta \leq 1\enspace. $$
#
# This is a probability distribution over the variable $\theta$. The distribution has two parameters, $a$ and $b$. The function $B(a,b)$ you may ignore for now; it simply ensures that the distribution integrates to 1, as it should (we will discuss this distribution at length in lecture 2). Here are some examples of what this distribution may look like, depending on how we select $a$ and $b$:

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=14)         # default fontsize
plt.rc('axes', titlesize=16)    # fontsize of the axes title
plt.rc('axes', labelsize=16)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)   # fontsize of the tick labels
plt.rc('ytick', labelsize=14)   # fontsize of the tick labels
plt.rc('legend', fontsize=16)   # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title
plt.rc('figure', titlesize=16)  # fontsize of the figure title


import numpy as np
from scipy.special import beta

def probability_density_function(theta, a, b):
    return theta**(a-1) * (1-theta)**(b-1) / beta(a,b)

theta = np.linspace(0, 1, num=100)

a_ = [3, 7, 2]
b_ = [2, 9, 5]

plt.figure()
for a, b in zip(a_, b_):
    plt.plot(theta, probability_density_function(theta, a, b), lw=2, label=f'$a={a}, b={b}$')
plt.xlim([0, 1])
plt.xlabel(r'$\theta$')
plt.ylabel(r'$p(\theta \mid a, b)$')
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %% [markdown]
# 1. Compute the value for $\theta$ that gives the maximum probability density, i.e.
#
# $ \hat{\theta}= \underset{\theta}{\operatorname{argmax}} p(\theta\mid a, b) \enspace.$
#
# Recall, to find the maximum of such a function, first take its logarithm, discard all terms that do not depend on $\theta$, find the derivative and set it to zero.
#
# 2. Copy-paste the above plottig code and add vertical lines (using ``plt.axvline()`` at the correct locations of the maxima of the three functions that are shown. (This acts as a sanity check! If your maxima are not at the tops of the curves, something is amiss!)

# %% [markdown]
# The logarithm of the function is log(p(theta | a, b)) = a-1 * log(theta) + (b - 1) * log(1 - theta) - log(B(a,b))
# The derivative of this logarithmic function with respect to theta is: d/d_theta log(P(theta | a, b)) = ((a-1)/theta) - ((b-1)/(1-theta))
# <br>
# Setting the derivative equal to zero we get:
# ((a-1)/theta) = ((b-1)/(1-theta))
# <br>
# When filling in the following values for a and b we get that:
# For a = 3, b = 2, the maximum occurs at θ = 2/3
# For a = 7, b = 9, the maximum occurs at θ = 3/7
# for a = 2, b = 5, the maximum occurs at θ = 1/5

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=14)         # default fontsize
plt.rc('axes', titlesize=16)    # fontsize of the axes title
plt.rc('axes', labelsize=16)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)   # fontsize of the tick labels
plt.rc('ytick', labelsize=14)   # fontsize of the tick labels
plt.rc('legend', fontsize=16)   # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title
plt.rc('figure', titlesize=16)  # fontsize of the figure title


import numpy as np
from scipy.special import beta

def probability_density_function(theta, a, b):
    return theta**(a-1) * (1-theta)**(b-1) / beta(a,b)

theta = np.linspace(0, 1, num=100)

a_ = [3, 7, 2]
b_ = [2, 9, 5]

plt.figure()
for a, b in zip(a_, b_):
    plt.plot(theta, probability_density_function(theta, a, b), lw=2, label=f'$a={a}, b={b}$')
plt.xlim([0, 1])
plt.xlabel(r'$\theta$')
plt.ylabel(r'$p(\theta \mid a, b)$')
plt.ylim(bottom=0)
plt.axvline(2/3)
plt.axvline(3/7)
plt.axvline(1/5)
plt.legend()
plt.show()

# %% [markdown]
# ## Another example
#
# Consider a toy spinner with a $[0,1]$ scale around its circumference; whatever number points up is the random number $x$ generated by this 'function'. Suppose that the spinner is modified in some way to give it a bias towards a certain outcome. The corresponding probability density function is $p(x)=6x(1-x)$, for $0 \leq x \leq 1$.
#
# 1. Use code in the previous question as a basis to make a plot of this probability density function.
#
# 2. If this is indeed a valid probability density function, it must be non-negative and it must integrate to 1. Show that this is indeed the case, by computing the integral $\int_0^1 p(x)\, \text{d}x$, and explaining that $p(x)\geq 0$ for $0\leq x \leq 1$.

# %% [markdown]
# The indefinite intefgral of p(x) with respect to x is: ∫6x(1-x)dx = -2x^3 + 3x^2
# To find the definite integral from 0 to 1, we evaluate the indefinite integral at the bounds x = 1 --> -2(1)^3 + 3(1)^2 = 1  and at x = 0 --> -2(0)^3 + 3(0)^2 = 0
# Subtracting the value at x = 0 from the value at x = 1 gives us the definite integral over the interval [0, 1]: 1 - 0 = 1
# the integral of p(x) over the interval [0, 1] is 1, satisfying the condition that a probability density function must integrate to 1 over its domain.
# <br>
# To show that p(x) ≥ 0 for 0 ≤ x ≤ 1 , we can examine the components of the function. The term x is non-negative  since x is within the interval [0,1].
# Similarly, (1 - x) is non-negative becasue x cannot exceed 1. The smallest value for (1 - x)  is zero, when x = 1. Since both x and (1 - x) are non-negative ove [0,1], their product is also non-negative.  Thus p(x) is non-negative for all x in the interval [0,1].

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rc('font', size=14)         # default fontsize
plt.rc('axes', titlesize=16)    # fontsize of the axes title
plt.rc('axes', labelsize=16)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)   # fontsize of the tick labels
plt.rc('ytick', labelsize=14)   # fontsize of the tick labels
plt.rc('legend', fontsize=16)   # legend fontsize
plt.rc('figure', titlesize=16)  # fontsize of the figure title
plt.rc('figure', titlesize=16)  # fontsize of the figure title

def density_function(x):
    return 6 * x * (1 - x)

xaxis = np.linspace(-1, 1, num=100)

plt.figure()
plt.plot(xaxis, density_function(xaxis), lw=2, label=f'$6x(1 - x)$')

plt.xlim([0, 1])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.axvline(1/2)
plt.ylim(bottom=0)
plt.legend()
plt.show()
